# %%
import pandas as pd

# %%
from pybaseball import batting_stats

# %%
df = batting_stats(2014, 2024, qual=1)

# %%
# Filter the dataframe to only include rows where the player is Aaron Judge
aaron_judge_df = df[df['Name'] == 'Aaron Judge']

# %%
aaron_judge_df
# Out:
#        IDfg  Season         Name Team  Age    G   AB   PA    H  1B  ...  \
# 155   15640    2024  Aaron Judge  NYY   32  158  559  704  180  85  ...
# 167   15640    2022  Aaron Judge  NYY   30  157  570  696  177  87  ...
# 257   15640    2017  Aaron Judge  NYY   25  155  542  678  154  75  ...
# 509   15640    2021  Aaron Judge  NYY   29  148  550  633  158  95  ...
# 480   15640    2018  Aaron Judge  NYY   26  112  413  498  115  66  ...
# 280   15640    2023  Aaron Judge  NYY   31  106  367  458   98  45  ...
# 560   15640    2019  Aaron Judge  NYY   27  102  378  447  103  57  ...
# 669   15640    2020  Aaron Judge  NYY   28   28  101  114   26  14  ...
# 5314  15640    2016  Aaron Judge  NYY   24   27   84   95   15   9  ...
#
#       maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xBA  xSLG  xwOBA  L-WAR
# 155   117.5    238.0     0.609     391  0.146  0.267  NaN   NaN    NaN   11.3
# 167   118.4    246.0     0.609     404  0.169  0.287  NaN   NaN    NaN   11.4
# ...

# %%
df_2014 = df

# %%
df_2013 = batting_stats(2003, 2013, qual=1)

# %%
total_data = pd.concat([df_2013, df_2014], ignore_index=True)

# %%
total_data.to_csv("original_data.csv", index=False)

# %%
df_2002 = batting_stats(1992, 2002, qual=1)

# %%
total_data
# Out:
#         IDfg  Season            Name   Team  Age    G   AB   PA    H   1B  \
# 0       1109    2004     Barry Bonds    SFG   39  147  373  617  135   60
# 1       1109    2003     Barry Bonds    SFG   38  130  390  550  133   65
# 2      10155    2013      Mike Trout    LAA   21  157  589  716  190  115
# 3      10155    2012      Mike Trout    LAA   20  139  559  639  182  117
# 4       9166    2012    Buster Posey    SFG   25  148  530  610  178  114
# ...      ...     ...             ...    ...  ...  ...  ...  ...  ...  ...
# 19928  11376    2014  Michael Choice    TEX   24   86  253  280   46   30
# 19929  12155    2024   Eddie Rosario  - - -   32   91  297  319   52   30
# 19930   3448    2019     Jeff Mathis    TEX   36   88  228  244   36   25
# 19931  11615    2024   Brandon Drury    LAA   31   97  325  360   55   44
# 19932   9272    2018     Chris Davis    BAL   32  128  470  522   79   51
#
#        ...  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xBA  xSLG  xwOBA  \
# ...

# %%
unique_values = total_data['Season'].unique()

print(unique_values)
# Out:
# [2004 2003 2013 2012 2007 2011 2005 2008 2009 2010 2006 2024 2022 2018
#  2015 2023 2017 2016 2019 2014 2021 2020]

# %%
df_1991 = batting_stats(1982, 1991, qual=1)

# %%
df_1981 = batting_stats(1972, 1981, qual=1)

# %%
df_1971 = batting_stats(1962, 1971, qual=1)

# %%
df_1961 = batting_stats(1952, 1961, qual=1)

# %%
df_1951 = batting_stats(1942, 1951, qual=1)

# %%
df_1941 = batting_stats(1932, 1941, qual=1)

# %%
df_1931 = batting_stats(1922, 1931, qual=1)

# %%
df_1921 = batting_stats(1912, 1921, qual=1)

# %%
df_1911 = batting_stats(1900, 1911, qual=1)

# %%
total_data = pd.concat([df_2013, df_2014, df_2002, df_1991, df_1981, df_1971, df_1961, df_1951, df_1941, df_1931, df_1921, df_1911,], ignore_index=True)

# %%
df_sorted = total_data.sort_values(by='Season')

# %%
unique_values = df_sorted['Season'].unique()

print(unique_values)
# Out:
# [1900 1901 1902 1903 1904 1905 1906 1907 1908 1909 1910 1911 1912 1913
#  1914 1915 1916 1917 1918 1919 1920 1921 1922 1923 1924 1925 1926 1927
#  1928 1929 1930 1931 1932 1933 1934 1935 1936 1937 1938 1939 1940 1941
#  1942 1943 1944 1945 1946 1947 1948 1949 1950 1951 1952 1953 1954 1955
#  1956 1957 1958 1959 1960 1961 1962 1963 1964 1965 1966 1967 1968 1969
#  1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983
#  1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997
#  1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011
#  2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024]

# %%
df_sorted.to_csv("all_data.csv", index=False)
